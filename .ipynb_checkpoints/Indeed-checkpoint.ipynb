# %%
import requests 
import re
from bs4 import BeautifulSoup 
import pandas as pd
import pymongo 
from nltk.corpus import stopwords
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
# Out:
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - There is no [win32] chromedriver for browser 89.0.4389 in cache
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/89.0.4389.23/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\Tim\.wdm\drivers\chromedriver\win32\89.0.4389.23]

# %%
stop_words = set(stopwords.words('english'))

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn) 
db = client.indeed
collection = db.posts

# %%
base_url='https://www.indeed.com/'
qloc='Washington+DC'
query='asp.net+-clearance'
for i in range(0,200,10):
    url = f"{base_url}jobs?q={query}&l={qloc}&jt=fulltime&start={i}"
    print(url)
    break;
    soup = BeautifulSoup(requests.get(url).text, "html.parser")  
    
    els = soup.select('.jobsearch-SerpJobCard') 
    if len(els) < 1:
        break
    for e in els: 
        if len(e) < 1:
            break
        dic = {}
        dic['query']=query
        dic['qloc']=qloc
        dic['title']=e.select('.title')[0].text.replace('\n','')
        dic['company']=e.select('.company')[0].text.replace('\n','')
        dic['location']=e.select('.location')[0].text.replace('\n','')
        dic['summary']=e.select('.summary')[0].text.replace('\n','')
        dic['entry']='-'.join([c for c in re.findall('\w*', f"{dic['title']}{dic['company']}") if c != '' and c not in stop_words])
        dic['date']=e.select('.date')[0].text.replace('\n','')
        if len(e.select('.salaryText')) > 0: 
            salaryText=e.select('.salaryText')[0].text.replace('\n','')
            dic['salary'] = re.findall('\d{2,3}\,\d{1,3}',salaryText) 
            if len(dic['salary']) > 1:
                dic['salarymin'] =  dic['salary'][0]
                dic['salarymax'] =  dic['salary'][1] 
        collection.delete_one(  {'entry': dic['entry']}  )
        collection.insert_one(dic)

# %%
df = pd.DataFrame(collection.find({}))
df['salarymin'] = df['salarymin'].apply(lambda x: str(x).replace(',', '')).astype('float') 
df['url'] = 'https://www.google.com/search?q=' + df['company'] + '+Careers'
df['url'] = df['url'].apply(lambda x: str(x).replace(' ', '%20'))
df['date'] = df['date'].apply(lambda x: re.sub('days ago|day ago|\+|Today|\s', '', x)).replace('','0').astype('float') 
df.sort_values(by='date', ascending=True, inplace=True) 
#df = df.loc[df.title.str.contains('Developer|Engineer|Software', regex=True)]
for i, r in df.iterrows():
    print(f"{r['title']} {r['company']} {r['url']}" )
df
# Out:
# .Net Developernew Bravent LLC https://www.google.com/search?q=Bravent%20LLC+Careers
# Tax Technology Support Analystnew Deloitte https://www.google.com/search?q=Deloitte+Careers
# .NET Developernew NETE an NTT DATA Company https://www.google.com/search?q=NETE%20an%20NTT%20DATA%20Company+Careers
# Tax Transformation .Net Developer - Seniornew Deloitte https://www.google.com/search?q=Deloitte+Careers
# Virtual Desktop Infrastructure (VDI) Delivery Engineer/Consu...new August Schell https://www.google.com/search?q=August%20Schell+Careers
# VMware Consultantnew August Schell Enterprises https://www.google.com/search?q=August%20Schell%20Enterprises+Careers
# .Net Developernew Technamo LLC https://www.google.com/search?q=Technamo%20LLC+Careers
# Senior .Net Engineer, LivingLens (Remote)new Medallia, Inc. https://www.google.com/search?q=Medallia,%20Inc.+Careers
# 1    601f3fc9e88677d0b76e85f4  asp.net+-clearance  Washington+DC
# 24   601f3fcae88677d0b76e8617  asp.net+-clearance  Washington+DC
# 19   601f3fcae88677d0b76e8610  asp.net+-clearance  Washington+DC
# 25   601f3fcae88677d0b76e861d  asp.net+-clearance  Washington+DC
# 79   601f3fcde88677d0b76e8683  asp.net+-clearance  Washington+DC
# ..                        ...                 ...            ...
# 101  601f3fcfe88677d0b76e86b1  asp.net+-clearance  Washington+DC
# 100  601f3fcfe88677d0b76e86b0  asp.net+-clearance  Washington+DC
# 99   601f3fcfe88677d0b76e869d  asp.net+-clearance  Washington+DC
# 22   601f3fcae88677d0b76e8613  asp.net+-clearance  Washington+DC
# 94   601f3fcee88677d0b76e8692  asp.net+-clearance  Washington+DC
#
#                                                  title  \
# 1                                    .Net Developernew
# 24                   Tax Technology Support Analystnew
# 19                                   .NET Developernew
# 25       Tax Transformation .Net Developer - Seniornew
# 79   Virtual Desktop Infrastructure (VDI) Delivery ...
# ..                                                 ...
# 101                               Full Stack Developer
# 100  Software Quality Assurance (QA) Specialist/App...
# 99                                  Software Developer
# 22                                C# Asp.Net Developer
# 94                              Security Administrator
#
#                         company                                location  \
# 1                   Bravent LLC                          Washington, DC
# 24                     Deloitte                            Suitland, MD
# 19     NETE an NTT DATA Company                              McLean, VA
# 25                     Deloitte                            Suitland, MD
# 79                August Schell  Rockville, MD 20850 (Town Center area)
# ..                          ...                                     ...
# 101                OneTouch HCM                        Gaithersburg, MD
# 100                   EdgeWorks                           Chantilly, VA
# 99                       INADEV                        McLean, VA 22102
# 22   Impresst Business Services                        Burtonsville, MD
# 94                  PharmD Live                          Washington, DC
#
#                                                summary  \
# 1    ASP.net: 1 year (Preferred).NET Framework, ASP...
# 24   The Application Support Analyst plays an integ...
# 19   NET Framework, SQL Server, Subversion, Ajax, T...
# 25   Net Developer you will be responsible for desi...
# 79   The VMware Delivery Engineer will be responsib...
# ..                                                 ...
# 101  Architect, design, create, and build web appli...
# 100  Develops and implements quality control method...
# 99   Research, design, develop, and test operating ...
# 22   Responsibilities may include different levels ...
# 94   We are seeking an IT Security Administrator wh...
#
#                                                  entry  date  \
# 1                          Net-DevelopernewBravent-LLC   0.0
# 24           Tax-Technology-Support-AnalystnewDeloitte   0.0
# 19               NET-DevelopernewNETE-NTT-DATA-Company   0.0
# 25   Tax-Transformation-Net-Developer-SeniornewDelo...   0.0
# 79   Virtual-Desktop-Infrastructure-VDI-Delivery-En...   1.0
# ..                                                 ...   ...
# 101                   Full-Stack-DeveloperOneTouch-HCM  30.0
# 100  Software-Quality-Assurance-QA-Specialist-Appli...  30.0
# 99                            Software-DeveloperINADEV  30.0
# 22       C-Asp-Net-DeveloperImpresst-Business-Services  30.0
# 94                   Security-AdministratorPharmD-Live  30.0
#
#                  salary  salarymin salarymax  \
# 1                    []        NaN       NaN
# 24                  NaN        NaN       NaN
# 19                  NaN        NaN       NaN
# 25                  NaN        NaN       NaN
# 79                  NaN        NaN       NaN
# ..                  ...        ...       ...
# 101                 NaN        NaN       NaN
# 100                 NaN        NaN       NaN
# 99   [140,000, 150,000]   140000.0   150,000
# 22                  NaN        NaN       NaN
# 94                  NaN        NaN       NaN
#
#                                                    url
# 1    https://www.google.com/search?q=Bravent%20LLC+...
# 24    https://www.google.com/search?q=Deloitte+Careers
# 19   https://www.google.com/search?q=NETE%20an%20NT...
# 25    https://www.google.com/search?q=Deloitte+Careers
# 79   https://www.google.com/search?q=August%20Schel...
# ..                                                 ...
# 101  https://www.google.com/search?q=OneTouch%20HCM...
# 100  https://www.google.com/search?q=EdgeWorks+Careers
# 99      https://www.google.com/search?q=INADEV+Careers
# 22   https://www.google.com/search?q=Impresst%20Bus...
# 94   https://www.google.com/search?q=PharmD%20Live+...
#
# [190 rows x 13 columns]

# %%
conn = 'mongodb://localhost:27017' 
cursor = collection.find(
    { }, {'_id': False})
df = pd.DataFrame(cursor)
df
# Out:
#                   query           qloc  \
# 0    asp.net+-clearance  Washington+DC
# 1    asp.net+-clearance  Washington+DC
# 2    asp.net+-clearance  Washington+DC
# 3    asp.net+-clearance  Washington+DC
# 4    asp.net+-clearance  Washington+DC
# ..                  ...            ...
# 185  asp.net+-clearance  Washington+DC
# 186  asp.net+-clearance  Washington+DC
# 187  asp.net+-clearance  Washington+DC
# 188  asp.net+-clearance  Washington+DC
# 189  asp.net+-clearance  Washington+DC
#
#                                                  title  \
# 0                             Software Developer IVnew
# 1                                    .Net Developernew
# 2                             ASP.Net / C# Programmers
# 3                                       .Net Developer
# 4                                    ASP.NET Developer
# ..                                                 ...
# 185  SDC2021-4082-.Net Architect/Subject Matter Exp...
# 186                                     .Net Developer
# 187  Senior Solutions Engineer - VMware Tanzu/MAPBU...
# 188                Software Engineering Technical Lead
# 189            100% REMOTE Senior Software Engineernew
#
#                          company              location  \
# 0                     LISCR, LLC      Dulles, VA 20166
# 1                    Bravent LLC        Washington, DC
# 2                      Marjen IT        Washington, DC
# 3                FAAZ Consulting        Washington, DC
# 4      Sriram Business Solutions        Washington, DC
# ..                           ...                   ...
# 185                 Serigor Inc.        Washington, DC
# 186       Maxim Healthcare Group    Columbia, MD 21046
# 187                       VMware        Washington, DC
# 188  LOCKHEED MARTIN CORPORATION     Herndon, VA 20171
# 189                  CyberCoders  Germantown, MD 20874
#
#                                                summary  \
# 0    The Software Developer IV responsibilities inc...
# 1    ASP.net: 1 year (Preferred).NET Framework, ASP...
# 2    NET and Visual C# in Oracle database supported...
# 3    Competence in writing clean, bug-free code as ...
# 4    Position requires a Bachelor Degree, 3-5 years...
# ..                                                 ...
# 185  Proficiency with .net CORE versions (1.0 to 3....
# 186  Net Developer designs, develops, and supports ...
# 187  The VMware Tanzu Solutions Engineer (SE) plays...
# 188  Develop and maintain complex systems that invo...
# 189  Realtime Systems interacting and controlling o...
#
#                                                  entry          date  \
# 0                    Software-Developer-IVnewLISCR-LLC    5 days ago
# 1                          Net-DevelopernewBravent-LLC         Today
# 2                       ASP-Net-C-ProgrammersMarjen-IT  30+ days ago
# 3                         Net-DeveloperFAAZ-Consulting   15 days ago
# 4           ASP-NET-DeveloperSriram-Business-Solutions  30+ days ago
# ..                                                 ...           ...
# 185  SDC2021-4082-Net-Architect-Subject-Matter-Expe...    3 days ago
# 186                Net-DeveloperMaxim-Healthcare-Group  30+ days ago
# 187  Senior-Solutions-Engineer-VMware-Tanzu-MAPBU-M...   17 days ago
# 188  Software-Engineering-Technical-LeadLOCKHEED-MA...  30+ days ago
# 189  100-REMOTE-Senior-Software-EngineernewCyberCoders    2 days ago
#
#                 salary salarymin salarymax
# 0                  NaN       NaN       NaN
# 1                   []       NaN       NaN
# 2                  NaN       NaN       NaN
# 3    [86,205, 142,944]    86,205   142,944
# 4                  NaN       NaN       NaN
# ..                 ...       ...       ...
# 185                 []       NaN       NaN
# 186                NaN       NaN       NaN
# 187                NaN       NaN       NaN
# 188                NaN       NaN       NaN
# 189                NaN       NaN       NaN
#
# [190 rows x 11 columns]

# %%
 
collection.delete_many(
     { 'entry': {'$regex': '^.*$', '$options': 'i'}}
)

# %%
browser = Browser('chrome', **executable_path, headless=False)

base_url='https://www.indeed.com/'
qloc='Washington+DC'
query='junior+data+python'
for i in range(0,20,10): 
    browser.visit(f"{base_url}jobs?q={query}&l={qloc}&jt=fulltime&start={i}")
    soup = BeautifulSoup( browser.html , 'html.parser') 
    for ele in soup.select('.jobsearch-SerpJobCard a.jobtitle'): 
        browser.click_link_by_id(f"{ele['id']}")

        with browser.get_iframe('vjs-container-iframe') as iframe: 
            soup = BeautifulSoup( iframe.html , 'html.parser')
            print(soup.select('#jobDescriptionText') == None)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-6-7802fb856fc9> in <module>
#       8     soup = BeautifulSoup( browser.html , 'html.parser')
#       9     for ele in soup.select('.jobsearch-SerpJobCard a.jobtitle'):
# ---> 10         browser.click_link_by_id(f"{ele['id']}")
#      11
#      12         with browser.get_iframe('vjs-container-iframe') as iframe:
#
# ~\anaconda3\lib\site-packages\splinter\driver\__init__.py in click_link_by_id(self, id)
#     400         Clicks in a link by id.
#     401         """
# --> 402         return self.find_by_id(id).first.click()
#     403
#     404     def quit(self):
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     786                 error = e
#     787
# --> 788         raise error
#     789
#     790     def check(self):
#
# ~\anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in click(self)
#     779         while time.time() < end_time:
#     780             try:
# --> 781                 return self._element.click()
#     782             except(
#     783                 ElementClickInterceptedException,
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <a target="_blank" id="jl_a6fed9ead0190337" href="/rc/clk?jk=a6fed9ead0190337&amp;fccid=985815297c2bf35b&amp;vjs=3" onmousedown="return rclk(this,jobmap[0],0);" onclick="setRefineByCookie(['jobtype']); return rclk(this,jobmap[0],true,0);" rel="noopener nofollow" title="Junior Social Scientist" class="jobtitle turnstileLink " data-tn-element="jobTitle">...</a> is not clickable at point (267, 450). Other element would receive the click: <div id="popover-form" class="popover-form popover-form-locationtst">...</div>
#   (Session info: chrome=89.0.4389.82)
