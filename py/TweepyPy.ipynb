# %%
import tweepy
import json
import pandas as pd
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
tweets = api.user_timeline(screen_name='itsJeffTiedrich', 
                           # 200 is the maximum allowed count
                           count=200,
                           include_rts = False, 
                           tweet_mode = 'extended'
                           )

for info in tweets[:2]:
    #print( info )
    print(f"\n {info['full_text']}")
# Out:
# {'created_at': 'Mon Mar 20 20:57:36 +0000 2023', 'id': 1637921352488304641, 'id_str': '1637921352488304641', 'full_text': '@TristanSnell "trump force one" *rolls eyes* \nhttps://t.co/ur14DMn5oR', 'truncated': False, 'display_text_range': [14, 69], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'TristanSnell', 'name': 'Tristan Snell', 'id': 15801906, 'id_str': '15801906', 'indices': [0, 13]}], 'urls': [{'url': 'https://t.co/ur14DMn5oR', 'expanded_url': 'https://twitter.com/itsJeffTiedrich/status/1501957164142931971', 'display_url': 'twitter.com/itsJeffTiedric…', 'indices': [46, 69]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1637916079904137217, 'in_reply_to_status_id_str': '1637916079904137217', 'in_reply_to_user_id': 15801906, 'in_reply_to_user_id_str': '15801906', 'in_reply_to_screen_name': 'TristanSnell', 'user': {'id': 1009577803304656896, 'id_str': '1009577803304656896', 'name': 'Jeff Tiedrich', 'screen_name': 'itsJeffTiedrich', 'location': '', 'description': "don't blame me, I voted for the email lady", 'url': 'https://t.co/ffCHQu1hps', 'entities': {'url': {'urls': [{'url': 'https://t.co/ffCHQu1hps', 'expanded_url': 'https://www.patreon.com/jefftiedrich', 'display_url': 'patreon.com/jefftiedrich', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1087545, 'friends_count': 121, 'listed_count': 3940, 'created_at': 'Wed Jun 20 23:24:40 +0000 2018', 'favourites_count': 17861, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 30268, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1009932396333031424/8FzKlCfB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1009932396333031424/8FzKlCfB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1009577803304656896/1537733095', 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1501957164142931971, 'quoted_status_id_str': '1501957164142931971', 'quoted_status_permalink': {'url': 'https://t.co/ur14DMn5oR', 'expanded': 'https://twitter.com/itsJeffTiedrich/status/1501957164142931971', 'display': 'twitter.com/itsJeffTiedric…'}, 'quoted_status': {'created_at': 'Thu Mar 10 16:24:27 +0000 2022', 'id': 1501957164142931971, 'id_str': '1501957164142931971', 'full_text': 'can we just talk for a minute about how broken inside and needy you have to be to name your plane Trump Force One', 'truncated': False, 'display_text_range': [0, 113], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1009577803304656896, 'id_str': '1009577803304656896', 'name': 'Jeff Tiedrich', 'screen_name': 'itsJeffTiedrich', 'location': '', 'description': "don't blame me, I voted for the email lady", 'url': 'https://t.co/ffCHQu1hps', 'entities': {'url': {'urls': [{'url': 'https://t.co/ffCHQu1h ...
# {'created_at': 'Mon Mar 20 20:54:14 +0000 2023', 'id': 1637920508313305089, 'id_str': '1637920508313305089', 'full_text': '@kyledcheney HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA HA oops I mean how terrible for melty farty Rudy', 'truncated': False, 'display_text_range': [13, 292], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'kyledcheney', 'name': 'Kyle Cheney', 'id': 23578274, 'id_str': '23578274', 'indices': [0, 12]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1637914850700525575, 'in_reply_to_status_id_str': '1637914850700525575', 'in_reply_to_user_id': 23578274, 'in_reply_to_user_id_str': '23578274', 'in_reply_to_screen_name': 'kyledcheney', 'user': {'id': 1009577803304656896, 'id_str': '1009577803304656896', 'name': 'Jeff Tiedrich', 'screen_name': 'itsJeffTiedrich', 'location': '', 'description': "don't blame me, I voted for the email lady", 'url': 'https://t.co/ffCHQu1hps', 'entities': {'url': {'urls': [{'url': 'https://t.co/ffCHQu1hps', 'expanded_url': 'https://www.patreon.com/jefftiedrich', 'display_url': 'patreon.com/jefftiedrich', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 1087545, 'friends_count': 121, 'listed_count': 3940, 'created_at': 'Wed Jun 20 23:24:40 +0000 2018', 'favourites_count': 17861, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 30268, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1009932396333031424/8FzKlCfB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1009932396333031424/8FzKlCfB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1009577803304656896/1537733095', 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 57, 'favorite_count': 1076, 'favorited': True, 'retweeted': False, 'lang': 'hu'}

# %%
search_results = api.search(q="BITCOIN", count=100)
for r in search_results['statuses']:
    print (r['text'])
    print ('------------')
# Out:
# Ethereum has taken what was a four-function calculator of a programming language in Bitcoin and turned it into a fu… https://t.co/FqRAMn9xLf
# ------------
# RT @DocumentingBTC: Africa now has the largest amount of #Bitcoin peer-to-peer trading volume in the world—even more than North America. 🌍…
# ------------
# RT @BitMartExchange: 📢 El Salvador installs 200 Bitcoin ATMs - allowing its citizens to convert the cryptocurrency into USD and withdraw it…
# ------------
# RT @MartyBent: The fact that the central bankers are clueless about how #Bitcoin is already helping millions of people around the world is…
# ------------
# RT @oytun86: Madem uzun bir aradan sonra Bitcoin 50 bin doların üzerine çıktı ben de bir çekiliş yapayım. 5 kişiye toplamda 5.000 TL’lik #B…
# ------------
# RT @adnradiochile: 🎙 EN VIVO | En #TuNuevoADN conversamos con @leomeyer sobre lo que deben saber los emprendedores acerca de las criptomone…
# ------------
# RT @MMCrypto: THE US-DOLLAR WILL CEASE TO EXIST, #BITCOIN HOWEVER IS FOR ETERNITY!
# ------------
# RT @amadeo1980: @antraxmiguel1 @nayibbukele @bukele @EmisarioJ @Roberto_Dubon @betObando44 @GuardianFAS297 @DinaArguetasv @JeannetteAguil1…
# ------------
# @echale_ganas_ @natasharothwell We don't  buy bitcoin
# We earn bitcoin From mining
# I could show you and few lucky p… https://t.co/khddNb1nej
# ------------
# RT @BitcoinMagazine: “People should be more exposed to #Bitcoin, less exposed to everything else in the world.” - @michael_saylor https://t…
# ------------
# RT @AnaisLocket: investir le bitcoin a changé ma vie
# ------------
# RT @22kMm3: 【仮想通貨プレゼント企画】
#
# 抽選で1名の人に10万円をビットコインで得た利益からプレゼントする
#
# ①イタチ@22kMm3
#  をフォロー
# ②このツイートをRT
#
# 締切:8月27日まで
#
# 当選者にはDMを送ります
#
# #BTC #Bitcoin https:…
# ------------
# RT @ISP_Protocol: ⭐️Our Private Presale for the early believers is live now to apply for the whitelist.
#
# 🌟Apply here: https://t.co/UsnFW16…
# ------------
# RT @DocumentingBTC: Africa now has the largest amount of #Bitcoin peer-to-peer trading volume in the world—even more than North America. 🌍…
# ------------
# El Salvador began installing Bitcoin ATMs, allowing its citizens to convert the cryptocurrency into U.S. dollars an… https://t.co/mhRvWFR8gg
# ------------
# RT @CRIPTOVISION1: Entrevista por @_TBlockchain 🤩
# 👉 Nelson Cabrera, CEO de Criptovision nos explica sobre el ecosistema #vsion
#  https://t.c…
# ------------
# RT @MaratonRadialSV: "Esto significa que la gente está preocupada porque todos sus ahorros se pueden convertir en Bitcoin".
# Merlin Barrera…
# ------------
# Bitcoin-Mining: Blackrock ist mit fast 383 Millionen US-Dollar investiert - BTC-ECHO | Bitcoin &amp; Blockchain Pioneer… https://t.co/owYFgGlqUg
# ------------
# @_VicenteSerrano @jantonioruizh @RicardoAnayaC @lopezobrador_ Después de leer los testimonios de otros sobre… https://t.co/9V2RjZQAZp
# ------------
# RT @alrawenet: #Bitcoin الآن قريب من الرقم اللي ذكرناه من 3 شهور 50500$ ،
# الآن ننتظر السلوك السعري للـ #BTC وتنويه للقديم التجميع يكون في ا…
# ------------
# RT @BitcoinMagazine: President Bukele: #Bitcoin legal tender launch to be supported by 200 new ATMs and 50 new branches.
#
# $BTC buying will…
# ------------
# RT @oytun86: Madem uzun bir aradan sonra Bitcoin 50 bin doların üzerine çıktı ben de bir çekiliş yapayım. 5 kişiye toplamda 5.000 TL’lik #B…
# ------------
# RT @DocumentingBTC: Africa now has the largest amount of #Bitcoin peer-to-peer trading volume in the world—even more than North America. 🌍…
# ------------
# RT @RBroughton180: $5000 Giveaway 😮😮🙏
#
# If #Bitcoin hits 60k again I will give 5 x people $1000 each so 5 x winners 👇
#
# RT &amp; Like this post
# F…
# ------------
# RT @LovecoinProject: 10,000 FREE LOVECOIN TOKEN GIVEAWAY - RETWEET THIS POST &amp; POST YOUR LOVECOIN ADDRESS IN THE COMMENT SECTION BELOW TO R…
# ------------
# RT @CryptoHunterTR: Evet bişeyler deniyor, bu analizi #nwc grubuna atmıştım eski zirve aşılırsa esas film o zaman başlar :)
#
# #btc #bitcoin…
# ------------
# @franfuentessv @nayibbukele @chivowallet Cómo puede recomendar tanta mentiras? A quienes tratan de engañar?
# En qué… https://t.co/uo4gediTeS
# ------------
# RT @oytun86: Madem uzun bir aradan sonra Bitcoin 50 bin doların üzerine çıktı ben de bir çekiliş yapayım. 5 kişiye toplamda 5.000 TL’lik #B…
# ------------
# RT @ForbesCrypto: #bitcoin reaches $50,000 for the first time since May. https://t.co/b6omAkeyqQ
# ------------
# @PositiveCrypto @getumbrel So simple to set up. Follow the instructions, it’s a walk in the park. Great feeling ver… https://t.co/NCAGKDCpMP
# ------------
# The elites and people in power in our society are not the intelligent, do-gooders you’ve been told to believe.
#
# Bit… https://t.co/1e7mp6MnxI
# ------------
# @airdropinspect Impresive and great project. I trust this project can be successfully
#
# @elham
# @Maryamhasnaa… https://t.co/O9avfRcvgq
# ------------
# RT @SherwinMAXINO: @SquareEnix -Cloud: Are my coins “in the clou-”
# -Lightning: What’s a “Lightning Network”?!
# -Squall: Whatever…
#
# Bank of M…
# ------------
# RT @CurrencyCom: How to make a #bitcoin video:
#
# 1. Make The Scream face 😱
# 2. You are good to go https://t.co/bM0sWr8uy6
# ------------
# Murat Ali Calman keriz silkelerken yakalandı diye bizi engellemiş ne alınıyon olum doğruyu söyledik diye #Bitcoin… https://t.co/ac8l5lamZf
# ------------
# So what you’re telling me is Cardano has outperformed Bitcoin snd Ethereum since basically its inception. Despite n… https://t.co/P3Nb09eKjG
# ------------
# ☠️Caution☠️
# This program is under construction
#
# ETHUSD
#
# 2021-08-24 06:32:42.715771 (JST)
#
# 3329.5 USD
#
# ---wait---
#
# #bitcoin #ethereum
# ------------
# RT @wallstwolverine: ¿En serio no hay ningún multimegamillonario con TOC que quiera redondear a los 50k? #Bitcoin
# ------------
# RT @CoinCornerMolly: This is of the best #Bitcoin conversations that I’ve heard in a long time!
# Great episode @jordanbpeterson @johnkvallis…
# ------------
# RT @Breez_Tech: Welcome @getSpendl, the latest addition to Breez's marketplace 💥
# With Spendl, you can top up a virtual credit card with Lig…
# ------------
# @waraujo64 @JaviSiman Después de leer los testimonios de otros sobre @DanielHarr8, me dio una buena estrategia y ta… https://t.co/GaMTZtyCfB
# ------------
# RT @business: El Salvador began installing Bitcoin ATMs, allowing its citizens to convert the cryptocurrency into U.S. dollars and withdraw…
# ------------
# RT @Klaasje16806968: #Bitcoin 🚨🚨📉📉 #bloodbath
# ------------
# Wow, this expert had made a forecast that bitcoin price went down from $64,000 to $33,000 on April 13 2021 and it w… https://t.co/nDIrfvBAtG
# ------------
# RT @JRNYcrypto: How many of you wish you went all in mid July? Even #Bitcoin is getting close to a 2x
#
# I hope everyone took the crash as a…
# ------------
# @SofaScoreBR @Brasileirao "Ain mas com que dinheiro?"
#
# Lista de financiadores no Corinthians:
#
# Lula
# Programas da su… https://t.co/h7ug9IyO8Z
# ------------
# RT @rcastano: To someday beat credit/debit cards in the USA, #Crypto payments should be widely accepted, instant/re-spendable, near 0 cost…
# ------------
# RT @seedphrase: Delisting #8348 at $200M
#
# CryptoPunks are eroding the store of value narrative from Bitcoin. If you think @Visa is the las…
# ------------
# RT @oytun86: Madem uzun bir aradan sonra Bitcoin 50 bin doların üzerine çıktı ben de bir çekiliş yapayım. 5 kişiye toplamda 5.000 TL’lik #B…
# ------------
# ЕСТЬ $40,000 ЧТО КУПИТЬ? XRP, BINANCE COIN, BITCOIN? ИНВЕСТИЦИИ В БИТКОИН | КАК ЗАРАБОТАТЬ НОВИЧКУ? CRYPTO CRYPTO N… https://t.co/zyM7SQ6U1u
# ------------
# RT @ElTrompudo2000: 💥LAS ESCUELAS HECHAS MIERDA, PERO LOS LADRONES INSTALAN CASETAS PARA SEGUIRNOS ROBANDO!💥
#
# Me cuenta un amigo que labora…
# ------------
# RT @CoinMarketCap: Coinbase Adding Bitcoin, Altcoins to Balance Sheet
#
# The top U.S. cryptocurrency exchange plans to spend $500 million plu…
# ------------
# RT @RodrigoHeralz: 💰👶🏻 Baby Boss Toshi
#
# ⌛️ Fair Launch August 23, 3pm UTC 😎 - Mooning now
# 🔥Babybosstoshi
# Next x100 GEMS Investors are rewar…
# ------------
# Viva la Vida!! El verdadero milagro es la Vida!!
#
# Anarquía, #Bitcoin, Filosofía, Música, Weed.
#
# Que chinguen a s… https://t.co/o0RnGhPnLc
# ------------
# @VailshireCap Meantime, I’ve been researching the ease with which I can sell my overseas rental property so that I… https://t.co/9JbYAVGyqx
# ------------
# RT @charliebilello: Bitcoin returns since 2010...
#
# $BTC https://t.co/nVqt7pHELU
# ------------
# RT @BITCOIN_AL_DIA: Análisis del mercado de criptomonedas.
# Retuitead por favor.
# #Bitcoin, corrige tras varias horas por encima de $ 50.000,…
# ------------
# @CryptoTownEU I believe this is a faithful project.The projector has a lot of attractions so hopefully the project… https://t.co/HGzyLakf9i
# ------------
# RT @FenixUlloaVP: Billetera “Chivo” clonada estafa a usuarios de bitcoin | 🤷🏼‍♀️ https://t.co/0H2hp94AQz
# ------------
# Good job @RiotBlockchain for increasing revenue in fiat and #Bitcoin   🙌
#
# 2020Q2: $2M | 213 ₿
# 2021Q2: $34M | 979 ₿… https://t.co/nZIxLOAdug
# ------------
# @ha1331 @BennettTomlin everything about this is a bitcoin-quality project
# ------------
# RT @DocumentingBTC: Africa now has the largest amount of #Bitcoin peer-to-peer trading volume in the world—even more than North America. 🌍…
# ------------
# RT @CDWGWAGov: It's time, IT — set the rules of the road for mobile #remote #100daysofcode #nowplaying #technology #business #video #amazon…
# ------------
# @marceaguirresv1 @waraujo64 Después de leer los testimonios de otros sobre @DanielHarr8, me dio una buena estrategi… https://t.co/D4knQkki01
# ------------
# RT @DBATTAGLIAYtube: La tasa hash muy pronto volverá a máximos y el precio de #Bitcoin también. https://t.co/C32t0ZfYR0
# ------------
# RT @DocumentingBTC: Africa now has the largest amount of #Bitcoin peer-to-peer trading volume in the world—even more than North America. 🌍…
# ------------
# @BitcoinSampo @1MarkMoss This is your ice cube. Protect it.
# #Bitcoin https://t.co/BHSeixfUGy
# ------------
# @franamati Increible noticia, descanse en paz Brenda. Recuerdo que fue de las primeras personas en presentarme Bitcoin cuando abrí Bitcoffe.
# ------------
# @boliviazica "Ain mas com que dinheiro?"
#
# Lista de financiadores no Corinthians:
#
# Lula
# Programas da sua mãe
# Jogo do… https://t.co/YZGJ8USJGG
# ------------
# RT @CDWGWAGov: It's time, IT — set the rules of the road for mobile #remote #100daysofcode #nowplaying #technology #business #video #amazon…
# ------------
# RT @econoar: Visa bought a CryptoPunk before a Bitcoin.
#
# 😂😂😂
# ------------
# @morbex_finance #MorbexFinance #Morbex #BEX #blockchain #cryptocurrency #technology #bitcoin #money #crypto… https://t.co/32G3laHq8B
# ------------
# @stupidtweeter02 @insecurehbo We don't  buy bitcoin
# We earn bitcoin From mining
# I could show you and few lucky peo… https://t.co/rmjfqviEZq
# ------------
# RT @BitcoinMagazine: Riot Blockchain's #Bitcoin mining revenue increased 1,540% in Q2 this year ⛏ https://t.co/dKnDlKyZqs
# ------------
# Hey I joined a network called SurveyJ and earned $906 today! You get paid for testing out new free apps and posting… https://t.co/ZXWpjZN49T
# ------------
# RT @Techconcatalina: 1 #Bitcoin = $5️⃣0️⃣.0️⃣0️⃣0️⃣ USD
#
# Salud Familia Cripto!! 🍾🥂
#
# Por los que aguantaron la caída!
# Lo mejor está por ve…
# ------------
# RT @OfficialBTCN: #BitcoinNetworks has been launched, and hit the market cap of 80 million in 10 mins of launch. The price has already gone…
# ------------
# RT @LovecoinProject: 10,000 FREE LOVECOIN TOKEN GIVEAWAY - RETWEET THIS POST &amp; POST YOUR LOVECOIN ADDRESS IN THE COMMENT SECTION BELOW TO R…
# ------------
# @ClairvoyantINVT @SEC_Enforcement @GeorgeASharp and look into the biggest manipulater on the planet elon too and his bitcoin and doge gains!
# ------------
# @ICOffenderII @Bitcoinclaat @fold_app Your fries are still awesome despite they take years off our lives, so thank… https://t.co/CnYa1RElWs
# ------------
# @Kyle23423206 @Bitcoin let’s prove Kyle23423206 wrong, if that is his real name
# ------------
# RT @Snaihtnirocccc: "Ain mas com que dinheiro?"
#
# Lista de financiadores do William no Corinthians:
#
# Lula
# Programas da sua mãe
# Jogo do bicho…
# ------------
# RT @coinacademy_fr: L'analyse technique de #Bitcoin et Chiliz $CHZ par @CryptoPicsou est disponible : https://t.co/wPgjSeIaiF
# ------------
# @pulte Bitcoin solves this
# ------------
# RT @CDWGWAGov: It's time, IT — set the rules of the road for mobile #remote #100daysofcode #nowplaying #technology #business #video #amazon…
# ------------
# 🔻🔻🔻 $KAVA Short Position(v1) 🔻🔻🔻
# Entry Price: 8.3824
# Target:8.3421
# Stop:8.4679
# #Binance #Bitcoin #Signals #Sell #KAVAUSDT #KAVA
# ------------
# RT @BitcoinMagazine: “People should be more exposed to #Bitcoin, less exposed to everything else in the world.” - @michael_saylor https://t…
# ------------
# RT @business: El Salvador began installing Bitcoin ATMs, allowing its citizens to convert the cryptocurrency into U.S. dollars and withdraw…
# ------------
# RT @BitcoinMagazine: Riot Blockchain's #Bitcoin mining revenue increased 1,540% in Q2 this year ⛏ https://t.co/dKnDlKyZqs
# ------------
# RT @MEXC_Global: #Bitcoin above $50,000🚀🚀🚀
#
# Have you been hodling? https://t.co/nHjyhY1uNf
# ------------
# #BITCOIN PUMP CRYPTO #ethereum PUMP CRYPTO #etherium PUMP BULLISH https://t.co/eDQCxghTia
# ------------
# RT @mquintanillae: ¿Cuánto va a costar poner todos esos cajeros Bitcoin y centros de atención al cliente?, ¿Quién está haciendo el desembol…
# ------------
# RT @Conocimiente: Siempre sospeché que todo esto del Bitcoin, tenía mucho que ver con las pandillas; ya que pueden con mayor facilidad y li…
# ------------
# RT @Charlie1337420: @GaryGensler
# Check this out.
#
# These are bitcoin open/close/high and volume.
#
# Notice anything? Yeah.. volume spiked on…
# ------------
# RT @gladstein: 1/ Want to know who controls Bitcoin?
#
# Read "The Blocksize War" by Jonathan Bier.
#
# This should be *required reading* for any…
# ------------
# Time, tide and #Bitcoin wait for no man (or woman): https://t.co/PsXMXeJkNH
# ------------
# From Student Loans To Bitcoin, Megan Thee Stallion Talks Financial Literacy https://t.co/LsimTFgu1u
# ------------
# RT @100trillionUSD: Current decline and fall of capitalism, extreme central bank money printing (QE / debasement), war on covid, rise of fa…
# ------------
# RT @rcastano: To someday beat credit/debit cards in the USA, #Crypto payments should be widely accepted, instant/re-spendable, near 0 cost…
# ------------
# RT @OfficialBTCN: #BitcoinNetworks has been launched, and hit the market cap of 80 million in 10 mins of launch. The price has already gone…
# ------------

# %%
public_tweets = api.user_timeline('pattonoswalt', count=25)
for d in public_tweets:
    print('---------------')
    print(d['text'])
# Out:
# ---------------
# New @harpers with essays by Garret Keizer, Ann Patchett, @harikunzru PLUS an article by @Bernstein?!?!? Whooo! (*Th… https://t.co/C1JDX4BQ9h
# ---------------
# 😂😂😂😂😂😂 https://t.co/tsHZZBrJg3
# ---------------
# RT @SimuLiu: “86% on RottenTomatoes? What happened to the other 14?”
#
# -my parents, probably
# ---------------
# hate that little asshole https://t.co/ExYRQCH7lB
# ---------------
# RT @TheOnion: Teary-Eyed Wrestlers Bid Farewell To Friends Made At SummerSlam https://t.co/xf26qV3kgo https://t.co/RPfbSChpgd
# ---------------
# RT @patrickcotnoir: The new @GLucasTalkShow episode with guests @PFTompkins and @richsommer is very, very fun...it featured unexpected call…
# ---------------
# 😂😂😂😂😂😂😂 https://t.co/6uJpbP7Fsy
# ---------------
# RT @dantelfer: Be suspicious of liberal vaccine talk. They are in the pocket of Big Alive and want you to not die so they can make money of…
# ---------------
# This is SO beyond gratifying, St. Louis! Second show added at @ThePageantSTL!!!! See you then? https://t.co/q4xoioBnVf
# ---------------
# ❤️❤️❤️❤️❤️❤️ https://t.co/NztQngvo8b
# ---------------
# RT @GerryDuggan: Save lives -- vote NO, California. Every vote counts.
# ---------------
# RT @MollyJongFast: Seems like voting NO on this is a good idea
# ---------------
# RT @perlapell: Here we come! https://t.co/Wh9jKoxRYR
# ---------------
# Glorious (sips Bellini) https://t.co/DaIGAJXtCZ
# ---------------
# Welp, you don't need to get me anything for Christmas baby. I'm good. https://t.co/1P4Zk5Cd6q
# ---------------
# RT @robintran04: Highly recommend https://t.co/96mmRT1Ll4
# ---------------
# I LOVE the end of video, where the journalist admits, "I was wrong and I just learned something." Wish that happene… https://t.co/7UuanPUqjm
# ---------------
# Oh, but hedge maze animals can come to life at a haunted hotel? Did you OVERLOOK that fact? God I love being a funn… https://t.co/LPxtiO1Xl3
# ---------------
# RT @VDOOZER: I’ve come to realize that Twitter is not a healthy place for me, neither in how it makes me feel, nor with how I behave on her…
# ---------------
# RT @MattOswaltVA: no worries, anti-vaxxers don't really start praying to God until they're on a ventilator
# ---------------
# 👇👇👇👇👇👇 https://t.co/CDuggEtCDf
# ---------------
# RT @BillyBaldwin: I’ve been on a cocktail of Ivermectin, Adrenochrome, Hydroxychloroquine, Clorox &amp; Tide Pods for a few weeks now… and I lo…
# ---------------
# Nöttap, husband of Htïderem, father of Ëcila. We have made our home in the lowlands of Öiduts Ytïc. https://t.co/35f8Cf7RTB
# ---------------
# RT @RubenBolling: Wow, I’d never seen this. In 1977, during a contract negotiation with Charles Schulz, the syndicate had Al Plastino (know…
# ---------------
# RT @Hugo_Book_Club: Dystopian fiction is when you take things that happen in real life to marginalized populations and apply them to people…

# %%
# User Accounts
news_orgs = ['BBC', 'CNN', 'CBSNews', 'FoxNews', 'nytimes']

# %%
#create dataframe with new columns
df_tweets = pd.DataFrame()
df_tweets['ORG'] = ''
df_tweets['TWEET_TEXT'] = ''
df_tweets['TWEET_DATE'] = ''

#make api call. run loop to save dataframe to local, get data from local only
#put the breaks on my loop to keep from too many calls.  Originaly set to 10,000
max_records = -1

i = 0

for org in news_orgs:
    if i > max_records:
        break
    public_tweets = api.user_timeline(org, count=100)
    for tweet in public_tweets:
        df_tweets.loc[i, 'ORG'] = org
        df_tweets.loc[i, 'TWEET_TEXT'] = tweet['text']
        df_tweets.loc[i, 'TWEET_DATE'] = tweet['created_at']
        i = i + 1
    
if len(df_tweets) > 1:
    df_tweets.to_csv('df_tweets.csv', index=False)
        
df_tweets=pd.read_csv('df_tweets.csv')
df_tweets

# %%
#convert dates
df_tweets['TWEET_DATE']=pd.to_datetime(df_tweets['TWEET_DATE']).dt.date
df_tweets.loc[df_tweets['TWEET_DATE'] == pd.to_datetime('2020-11-15')]

# %%
analyser = SentimentIntensityAnalyzer()
print(analyser.polarity_scores('LOVE'))
print(analyser.polarity_scores('EVIL'))

# %%
#create plot
df_filtered = df_tweets

for i, row in df_tweets.iterrows():
    dic = analyser.polarity_scores(row['TWEET_TEXT'])
    df_tweets.loc[i, 'Negative'] = dic['neg']
    df_tweets.loc[i, 'Neutral'] = dic['neu']
    df_tweets.loc[i, 'Positive'] = dic['pos']
    df_tweets.loc[i, 'Compound'] = dic['compound']

df_filtered = df_filtered[df_filtered['TWEET_DATE'] == pd.to_datetime('2020-11-15')]
for org in news_orgs:
    df=df_filtered[df_filtered['ORG']==org]
    df=df.sort_values(by='TWEET_DATE', inplace=False)
    plt.scatter( range(len(df)), df['Compound'])
#format plot    
plt.style.use('ggplot')   
plt.title('Sentiment Analysis of Media Tweets November 15, 2020')
plt.ylabel('Tweet Polarity')
plt.xlabel('Tweets Ago')

#export .png of figure
plt.savefig("Fig1.png")
plt.show()

# %%
for org in news_orgs:
    df=df_filtered[df_filtered['ORG']==org]
    df=df.sort_values(by='TWEET_DATE', inplace=False)
    plt.bar(df['ORG'], df['Compound'])
#format plot    
plt.style.use('ggplot')   
plt.title('Overall Media Stentiment Based on Twitter November 15, 2020')
plt.ylabel('Tweet Polarity')
plt.xlabel('Tweets Ago')

#export .png of figure
plt.savefig("Fig2.png")
plt.show()
