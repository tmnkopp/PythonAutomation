# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Mouse_metadata.csv')
df.set_index('Mouse ID', inplace=True)

# %%
s = set(df.index.values)

# %%
d = pd.DataFrame( )
d['M_ID'] = list(s) 
d['M_VAL'] = np.random.randint(low=1, high=100, size=len(s) )
d.sort_values('M_ID', inplace=True)
d.set_index('M_ID', inplace=True)


d['M_VAL'].values.reshape(-1,1)
# Out:
# array([[ 4],
#        [73],
#        [35],
#        [99],
#        [65],
#        [22],
#        [40],
#        [27],
#        [ 6],
#        [31],
#        [13],
#        [43],
#        [28],
#        [ 8],
#        [33],
#        [89],
#        [84],
#        [40],
#        [22],
#        [47],
#        [49],
#        [53],
#        [45],
#        [95],
#        [97],
#        [25],
#        [12],
#        [75],
#        [71],
#        [15],
#        [66],
#        [30],
#        [56],
#        [65],
#        [46],
#        [ 7],
#        [ 2],
#        [57],
#        [34],
#        [95],
#        [69],
#        [25],
#        [16],
#        [68],
#        [16],
#        [18],
#        [52],
#        [49],
#        [18],
#        [77],
#        [81],
#        [81],
#        [92],
#        [66],
#        [58],
#        [46],
#        [20],
#        [56],
#        [ 4],
#        [27],
#        [93],
#        [ 2],
#        [56],
#        [32],
#        [49],
#        [59],
# ...

# %%
d.loc['a203']
# Out:
# M_VAL    4
# Name: a203, dtype: int32

# %%
sr = pd.read_csv('data/Study_results.csv')
mm = pd.read_csv('data/Mouse_metadata.csv')

# %%
df = pd.merge(sr, mm, on='Mouse ID', how='left'  )
df.drop_duplicates(subset =['Mouse ID', 'Timepoint'], keep = False, inplace = True)
df.head(2)
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29

# %%
g = df.groupby('Drug Regimen')['Tumor Volume (mm3)', 'Timepoint' ]
g.describe()
# Out:
# <ipython-input-136-09a98ead79de>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   g = df.groupby('Drug Regimen')['Tumor Volume (mm3)', 'Timepoint' ]
#              Tumor Volume (mm3)                                             \
#                           count       mean       std        min        25%
# Drug Regimen
# Capomulin                 230.0  40.675741  4.994774  23.343598  37.685933
# Ceftamin                  178.0  52.591172  6.268188  45.000000  47.208427
# Infubinol                 178.0  52.884795  6.567243  36.321346  47.312353
# Ketapril                  188.0  55.235638  8.279709  45.000000  48.232987
# Naftisol                  186.0  54.331565  8.134708  45.000000  47.285874
# Placebo                   181.0  54.033581  7.821003  45.000000  47.459053
# Propriva                  151.0  52.458254  6.637293  45.000000  47.011050
# ...
